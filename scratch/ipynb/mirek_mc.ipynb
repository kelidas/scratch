# %%
from IPython.display import FileLink
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import skew, kurtosis, spearmanr
plt.rc('savefig', dpi=150)
DIR = '/media/raid/Zaloha/vypocty/mirek_Bb/mc/'
freet_input = np.loadtxt(os.path.join(DIR, 'mc.txt'))

# %%
task_files = [v for v in os.listdir(DIR) if os.path.splitext(v)[1]=='.in']
task_files.sort()

# %%
data = []
for i in task_files:
    filename = os.path.splitext(i)[0]
    datafile = os.path.join(DIR, 'results', filename + '.txt')
    if os.path.exists(datafile):
        d = np.loadtxt(datafile)
        data.append(d)

# %%
print len(data)
# Out:
# 1093

# %% [markdown]
# Force vs. CMOD
# =================

# %%
for i in range(len(data)):
    plt.plot(data[i][:,6]-data[i][:,5], data[i][:,3], linewidth=.5)

plt.show()

# %% [markdown]
# Force vs. vertical displacement in the middle of the span
# =========================================================

# %%
for i in range(len(data)):
    plt.plot(-data[i][:,1], data[i][:,3], linewidth=.5)

plt.show()

# %% [markdown]
# Analysis of peak values (force and CMOD)
# =========================================

# %%
peak_force = []
peak_cmod = []
for i in range(len(data)):
    force = data[i][:,3]
    cmod = data[i][:,6]-data[i][:,5]
    w = -data[i][:, 1]
    peak_force.append(force.max())
    peak_cmod.append(cmod[(force==force.max())[0]])
peak_cmod = np.array(peak_cmod)
peak_force = np.array(peak_force)

# %%
print 'mean value', np.mean(peak_cmod)
print 'standard deviation', np.std(peak_cmod, ddof=1)
print 'skewness', skew(peak_cmod)
print 'kurtosis', kurtosis(peak_cmod)
plt.hist(peak_cmod, bins=50, normed=True)
plt.show()
# Out:
# mean value 0.000106765703733
# standard deviation 1.66923553759e-05
# skewness 1.06896827873
# kurtosis 1.95304334145

# %%
print 'mean value', np.mean(peak_force)
print 'standard deviation', np.std(peak_force, ddof=1)
print 'skewness', skew(peak_force)
print 'kurtosis', kurtosis(peak_force)
plt.hist(peak_force, bins=50, normed=True)
plt.show()
# Out:
# mean value 4442.97344922
# standard deviation 822.877903079
# skewness -0.204401657162
# kurtosis 0.121636554675

# %% [markdown]
# Correlation
# ==============
# correlation of Freet input parameters [$E$, $f_t$, $G_f$]

# %%
spearmanr(freet_input)
# Out:
# (array([[ 1.        ,  0.51525157,  0.30761961],
#        [ 0.51525157,  1.        ,  0.72238774],
#        [ 0.30761961,  0.72238774,  1.        ]]),
#  array([[  0.00000000e+000,   0.00000000e+000,   1.05543979e-214],
#        [  0.00000000e+000,   0.00000000e+000,   0.00000000e+000],
#        [  1.05543979e-214,   0.00000000e+000,   0.00000000e+000]]))

# %% [markdown]
# correlation [$E$, $f_t$, $G_f$, cmod, $F$]

# %%
corr_data = freet_input[:len(data),:]

# %%
corr_data = np.vstack((peak_cmod, peak_force))
corr_data = np.hstack((freet_input[:len(data),:], corr_data.T))
corr_arr = spearmanr(corr_data)

# %%
ms=1
plt.subplot(441)
plt.title('$f_t$')
plt.plot(corr_data[:,0], corr_data[:,1], 'bx', ms=ms)
plt.xticks([])
plt.yticks([])
plt.ylabel('$E$')

plt.subplot(442)
plt.title('$G_f$')
plt.plot(corr_data[:,0], corr_data[:,2], 'bx', ms=ms)
plt.xticks([])
plt.yticks([])

plt.subplot(443)
plt.title('cmod')
plt.plot(corr_data[:,0], corr_data[:,3], 'bx', ms=ms)
plt.xticks([])
plt.yticks([])

plt.subplot(444)
plt.title('$F$')
plt.plot(corr_data[:,0], corr_data[:,4], 'bx', ms=ms)
plt.xticks([])
plt.yticks([])

plt.subplot(446)
plt.plot(corr_data[:,1], corr_data[:,2], 'bx', ms=ms)
plt.xticks([])
plt.yticks([])
plt.ylabel('$f_t$')

plt.subplot(447)
plt.plot(corr_data[:,1], corr_data[:,3], 'bx', ms=ms)
plt.xticks([])
plt.yticks([])

plt.subplot(448)
plt.plot(corr_data[:,1], corr_data[:,4], 'bx', ms=ms)
plt.xticks([])
plt.yticks([])

plt.subplot(4,4,11)
plt.plot(corr_data[:,2], corr_data[:,3], 'bx', ms=ms)
plt.xticks([])
plt.yticks([])
plt.ylabel('$G_f$')

plt.subplot(4,4,12)
plt.plot(corr_data[:,2], corr_data[:,4], 'bx', ms=ms)
plt.xticks([])
plt.yticks([])

plt.subplot(4,4,16)
plt.plot(corr_data[:,3], corr_data[:,4], 'bx', ms=ms)
plt.xticks([])
plt.yticks([])
plt.ylabel('cmod')

print corr_arr[0]
plt.show()
# Out:
# [[ 1.          0.50151642  0.29303965 -1.          0.60204209]
#  [ 0.50151642  1.          0.70769684 -0.50151642  0.9110358 ]
#  [ 0.29303965  0.70769684  1.         -0.29303965  0.88263204]
#  [-1.         -0.50151642 -0.29303965  1.         -0.60204209]
#  [ 0.60204209  0.9110358   0.88263204 -0.60204209  1.        ]]

# %% [markdown]
# Per partes analysis
# ====================

# %%
n = 3**np.arange(10)
idx_end = np.cumsum(n)
idx_start = idx_end - n
idx_start, idx_end
# Out:
# (array([   0,    1,    4,   13,   40,  121,  364, 1093, 3280, 9841]),
#  array([    1,     4,    13,    40,   121,   364,  1093,  3280,  9841, 29524]))

# %%
mean_vals = []
std_vals = []
color = ['blue','green','red','black','cyan','magenta','#CCCCCC','#EEEEEE','red','red']
label = ['E', 'F_t', 'G_f', 'cmod', 'F']
for i in range(10):
    if corr_data.shape[0]>=idx_end[i]:
        m = np.mean(corr_data[idx_start[i]:idx_end[i], :], axis=0)
        s = np.std(corr_data[idx_start[i]:idx_end[i], :], axis=0)
        mean_vals.append(m)
        std_vals.append(s)
mean_vals = np.array(mean_vals)
std_vals = np.array(std_vals)

for i in range(mean_vals.shape[1]):
    plt.figure(0)
    plt.plot(mean_vals[:, i]/mean_vals[-1, i], '-x', color=color[i], label=label[i])
    #plt.plot((mean_vals[:, i]+std_vals[:, i])/mean_vals[:, i], '--x', color=color[i], linewidth=0.5)
    #plt.plot((mean_vals[:, i]-std_vals[:, i])/mean_vals[:, i], '--x', color=color[i], linewidth=0.5)
    #plt.yscale('log')
    plt.ylim(0.5,1.4)
    plt.legend(loc='best')
    
    plt.figure(1)
    plt.plot(np.arange(std_vals.shape[0]-1)+1, (std_vals[:, i]/std_vals[-1,i])[1:], '-x', color=color[i], label=label[i])
    plt.xlim(0,std_vals.shape[0]-1)
    plt.legend(loc='best')
    
#plt.figure(2)
#plt.plot(mean_vals/mean_vals[-1], '-x', color=color[i])
#plt.plot((mean_vals+std_vals)/mean_vals[-1], '--x', color=color[i], linewidth=0.5)
#plt.plot((mean_vals-std_vals)/mean_vals[-1], '--x', color=color[i], linewidth=0.5)
#plt.yscale('log')
#plt.ylim(0.5,2)

#plt.figure(1)
#plt.plot(std_vals/std_vals[-1], '-x', color=color[i])

plt.show()

# %%
color = ['black','#222222','#444444','#666666','#888888','#AAAAAA','#CCCCCC','#EEEEEE','red','red']
for i in range(10):
    if corr_data.shape[0]>=idx_end[i]:
        for j in range(idx_start[i],idx_end[i]):
            plt.plot(-data[j][:,1], data[j][:,3], color=color[i], zorder=10-i, linewidth=.2*(10-i))

plt.show()

# %%
for i in range(3,10):
    if corr_data.shape[0]>=idx_end[i]:
        plt.subplot(121)
        plt.hist(peak_force[idx_start[i]:idx_end[i]], bins=10, normed=True, histtype='bar', color=color[i], alpha=.7)
        
        plt.subplot(122)
        plt.hist(peak_cmod[idx_start[i]:idx_end[i]], bins=10, normed=True, histtype='bar', color=color[i], alpha=.7)

plt.tight_layout()
plt.show()
